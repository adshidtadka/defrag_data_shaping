# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import pylab
from pylab import rcParams

# %%
df_blocking_hop0  = pd.read_csv('../20181219_hop_euro_0/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop1  = pd.read_csv('../20181219_hop_euro_1/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop2  = pd.read_csv('../20181219_hop_euro_2/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop3  = pd.read_csv('../20181219_hop_euro_3/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop4  = pd.read_csv('../20181219_hop_euro_4/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop5  = pd.read_csv('../20181219_hop_euro_5/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop6  = pd.read_csv('../20181219_hop_euro_6/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop7  = pd.read_csv('../20181219_hop_euro_7/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop8  = pd.read_csv('../20181219_hop_euro_8/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop9  = pd.read_csv('../20181219_hop_euro_9/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
# df_blocking_hop10 = pd.read_csv('../20181219_hop_euro_10/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
# df_blocking_hop11 = pd.read_csv('../20181219_hop_euro_11/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
# df_blocking_hop12 = pd.read_csv('../20181219_hop_euro_12/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
# df_blocking_hop13 = pd.read_csv('../20181219_hop_euro_13/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
# df_blocking_hop14 = pd.read_csv('../20181219_hop_euro_14/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )

# %%
for index, row in df_blocking_hop0.iterrows():
    df_blocking_hop0.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop1.iterrows():
    df_blocking_hop1.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop2.iterrows():
    df_blocking_hop2.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop3.iterrows():
    df_blocking_hop3.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop4.iterrows():
    df_blocking_hop4.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop5.iterrows():
    df_blocking_hop5.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop6.iterrows():
    df_blocking_hop6.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop7.iterrows():
    df_blocking_hop7.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop8.iterrows():
    df_blocking_hop8.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop9.iterrows():
    df_blocking_hop9.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
# for index, row in df_blocking_hop10.iterrows():
#     df_blocking_hop10.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
# for index, row in df_blocking_hop11.iterrows():
#     df_blocking_hop11.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
# for index, row in df_blocking_hop12.iterrows():
#     df_blocking_hop12.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
# for index, row in df_blocking_hop13.iterrows():
#     df_blocking_hop13.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
# for index, row in df_blocking_hop14.iterrows():
#     df_blocking_hop14.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]

# %%
df_blocking_hop0 =  df_blocking_hop0.replace(0, np.NaN)
df_blocking_hop1 =  df_blocking_hop1.replace(0, np.NaN)
df_blocking_hop2 =  df_blocking_hop2.replace(0, np.NaN)
df_blocking_hop3 =  df_blocking_hop3.replace(0, np.NaN)
df_blocking_hop4 =  df_blocking_hop4.replace(0, np.NaN)
df_blocking_hop5 =  df_blocking_hop5.replace(0, np.NaN)
df_blocking_hop6 =  df_blocking_hop6.replace(0, np.NaN)
df_blocking_hop7 =  df_blocking_hop7.replace(0, np.NaN)
df_blocking_hop8 =  df_blocking_hop8.replace(0, np.NaN)
df_blocking_hop9 =  df_blocking_hop9.replace(0, np.NaN)
# df_blocking_hop10 =  df_blocking_hop10.replace(0, np.NaN)
# df_blocking_hop11 =  df_blocking_hop11.replace(0, np.NaN)
# df_blocking_hop12 =  df_blocking_hop12.replace(0, np.NaN)
# df_blocking_hop13 =  df_blocking_hop13.replace(0, np.NaN)
# df_blocking_hop14 =  df_blocking_hop14.replace(0, np.NaN)

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")
plt.minorticks_off()
plt.plot(df_blocking_hop0['load'], df_blocking_hop0['Without defragmentation'], marker='x',  color="black")
plt.plot(df_blocking_hop0['load'], df_blocking_hop0['Conventional'], label=('Conventional'), marker='^',  color="red")

plt.plot(df_blocking_hop0['load'], df_blocking_hop0['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 0)'), marker='.',  color="blue", linestyle='-')

plt.plot(df_blocking_hop2['load'], df_blocking_hop2['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 2)'), marker='.',  color="blue", linestyle='--')

# plt.plot(df_blocking_hop6['load'], df_blocking_hop6['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 6)'), marker='.',  color="blue", linestyle='-.')

plt.plot(df_blocking_hop5['load'], df_blocking_hop5['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 5)'), marker='.',  color="blue", linestyle=':')

plt.xticks([350, 360, 370, 380, 390, 400, 410, 420, 430, 440])

# plt.xlim([350, 430])
plt.yticks([1, 0.1, 0.01, 0.001, 0.0001, 0.00001])

plt.xlabel("Traffic load [Erlang]", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="lower right")
plt.savefig("../../sawa_paper/sawa/20181223_journal_sawa/fig/net12_hop.pdf")
plt.show()

# %%
df_ramda60 = pd.DataFrame(df_blocking_hop0.iloc[3]).T.rename(index={3:0})
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop1.iloc[3]).T.rename(index={3:1}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop2.iloc[3]).T.rename(index={3:2}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop3.iloc[3]).T.rename(index={3:3}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop4.iloc[3]).T.rename(index={3:4}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop5.iloc[3]).T.rename(index={3:5}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop6.iloc[3]).T.rename(index={3:6}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop7.iloc[3]).T.rename(index={3:7}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop8.iloc[3]).T.rename(index={3:8}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop9.iloc[3]).T.rename(index={3:9}))
# df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop10.iloc[1]).T.rename(index={1:10}))
# df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop11.iloc[1]).T.rename(index={1:11}))
# df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop12.iloc[1]).T.rename(index={1:12}))
# df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop13.iloc[1]).T.rename(index={1:13}))
# df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop14.iloc[1]).T.rename(index={1:14}))
df_ramda60
# Out:
#     load  Without defragmentation  Conventional  Proposed  \
# 0  380.0                   0.0867        0.0597    0.0004
# 1  380.0                   0.0865        0.0601    0.0023
# 2  380.0                   0.0871        0.0601    0.0037
# 3  380.0                   0.0883        0.0617    0.0046
# 4  380.0                   0.0859        0.0604    0.0049
# 5  380.0                   0.0884        0.0621    0.0048
# 6  380.0                   0.0858        0.0614    0.0049
# 7  380.0                   0.0875        0.0604    0.0047
# 8  380.0                   0.0875        0.0604    0.0047
# 9  380.0                   0.0875        0.0604    0.0047
#
#    Conventional with SSR-LNO  Proposed with SSRR-LNO
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...

# %%
ave = df_ramda60.mean()
for index, row in df_ramda60.iterrows():
    df_ramda60.loc[index, 'Without defragmentation'] = ave['Without defragmentation']
    df_ramda60.loc[index, 'Conventional'] = ave['Conventional']

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")

plt.plot(df_ramda60.index, df_ramda60['Without defragmentation'], label=('Without defragmentation'), marker='.',  color="black", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Conventional'], label=('Conventional (' + r'$\lambda$' + ' = 380)'), marker='.',  color="red", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Proposed'], label=('Proposed (' + r'$\lambda$' + ' = 380)'), marker='.',  color="blue", linestyle='-')

# plt.xticks([2, 5, 10, 15, 20])
plt.yticks([1, 0.1, 0.01, 0.001, 0.0001])

plt.minorticks_off()

plt.xlabel("Maximum allowable number of hops", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="upper right")
plt.savefig("../../sawa_paper/sawa/20181223_journal_sawa/fig/net12_hop_num.pdf")
plt.show()
plt.close()
