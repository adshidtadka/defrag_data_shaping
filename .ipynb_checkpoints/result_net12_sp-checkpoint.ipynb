# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import pylab
from pylab import rcParams

# %%
df_blocking_001 = pd.read_csv('../20181014_net11_speed01/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_002 = pd.read_csv('../20181014_net11_speed02/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_003 = pd.read_csv('../20181014_net11_speed03/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_004 = pd.read_csv('../20181014_net11_speed04/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_005 = pd.read_csv('../20181014_net11_speed05/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_01 =  pd.read_csv('../20181014_net11_speed1/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )

# %%
for index, row in df_blocking_001.iterrows():
    df_blocking_001.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_002.iterrows():
    df_blocking_002.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_003.iterrows():
    df_blocking_003.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_004.iterrows():
    df_blocking_004.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_005.iterrows():
    df_blocking_005.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_01.iterrows():
    df_blocking_01.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]

# %%
df_blocking_001 = df_blocking_001.replace(0, np.nan)
df_blocking_002 = df_blocking_002.replace(0, np.nan)
df_blocking_003 = df_blocking_003.replace(0, np.nan)
df_blocking_004 = df_blocking_004.replace(0, np.nan)
df_blocking_005 = df_blocking_005.replace(0, np.nan)
df_blocking_01 = df_blocking_01.replace(0, np.nan)

# %%
print(df_blocking_002)
# Out:
#    load  speed  Without defragmentation  Conventional  Proposed  \
# 0   350      1                   0.0377        0.0294    0.0007
# 1   360      1                   0.0433        0.0353    0.0018
# 2   370      1                   0.0525        0.0415    0.0038
# 3   380      1                   0.0597        0.0480    0.0073
# 4   390      1                   0.0650        0.0541    0.0099
# 5   400      1                   0.0717        0.0606    0.0166
# 6   410      1                   0.0777        0.0671    0.0203
# 7   420      1                   0.0844        0.0732    0.0281
# 8   430      1                   0.0925        0.0796    0.0334
# 9   440      1                   0.1016        0.0885    0.0411
#
#    Conventional with SSR-LNO  Proposed with SSRR-LNO
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# ...

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")
plt.minorticks_off()
plt.plot(df_blocking_001['load'], df_blocking_001['Without defragmentation'], marker='x',  color="black")

plt.plot(df_blocking_001['load'], df_blocking_001['Conventional'], label=('Conventional (' + r'$\beta$' + ' = 0.1)'), marker='^',  color="red")
plt.plot(df_blocking_001['load'], df_blocking_001['Proposed'], label=('Proposed (' + r'$\beta$' + ' = 0.1)'), marker='.',  color="blue")

plt.plot(df_blocking_002['load'], df_blocking_002['Conventional'], label=('Conventional (' + r'$\beta$' + ' = 0.2)'), marker='^',  color="red", linestyle='--')
plt.plot(df_blocking_002['load'], df_blocking_002['Proposed'], label=('Proposed (' + r'$\beta$' + ' = 0.2)'), marker='.',  color="blue", linestyle='--')

plt.plot(df_blocking_003['load'], df_blocking_003['Conventional'], label=('Conventional (' + r'$\beta$' + ' = 0.3)'), marker='^',  color="red", linestyle=':')
plt.plot(df_blocking_003['load'], df_blocking_003['Proposed'], label=('Proposed (' + r'$\beta$' + ' = 0.3)'), marker='.',  color="blue", linestyle=':')

# plt.plot(df_blocking_004['load'], df_blocking_004['Conventional'], label=('Conventional (' + r'$\beta$' + ' = 0.4)'), marker='^',  color="red", linestyle='-.')
# plt.plot(df_blocking_004['load'], df_blocking_004['Proposed'], label=('Proposed (' + r'$\beta$' + ' = 0.4)'), marker='.',  color="blue", linestyle='-.')

plt.yticks([1,0.1, 0.01,0.001, 0.0001])

plt.xlabel("Traffic load [Erlang]") # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="lower right")
plt.savefig("../../sawa_paper/sawa/20180921_journal/fig/speeding_net12.pdf")
plt.show()
plt.close()
