# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import pylab
from pylab import rcParams

# %%
df_blocking_hop2 = pd.read_csv('../20181018_abiline_sp1_hop2/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop3 = pd.read_csv('../20181018_abiline_sp1_hop3/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop4 = pd.read_csv('../20181018_abiline_sp1_hop4/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop5 = pd.read_csv('../20181018_abiline_sp1_hop5/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop6 = pd.read_csv('../20181019_abiline_sp1_hop6/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop7 = pd.read_csv('../20181019_abiline_sp1_hop7/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop8 = pd.read_csv('../20181019_abiline_sp1_hop8/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop9 = pd.read_csv('../20181019_abiline_sp1_hop9/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop10 = pd.read_csv('../20181019_abiline_sp1_hop10/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop11 = pd.read_csv('../20181019_abiline_sp1_hop11/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop12 = pd.read_csv('../20181019_abiline_sp1_hop12/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop13 = pd.read_csv('../20181019_abiline_sp1_hop13/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop14 = pd.read_csv('../20181019_abiline_sp1_hop14/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop15 = pd.read_csv('../20181019_abiline_sp1_hop15/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop99999 = pd.read_csv('../20181021_abiline_sp1_hop99999/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )

# %%
for index, row in df_blocking_hop2.iterrows():
    df_blocking_hop2.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop3.iterrows():
    df_blocking_hop3.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop4.iterrows():
    df_blocking_hop4.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop5.iterrows():
    df_blocking_hop5.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop6.iterrows():
    df_blocking_hop6.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop7.iterrows():
    df_blocking_hop7.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop8.iterrows():
    df_blocking_hop8.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop9.iterrows():
    df_blocking_hop9.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop10.iterrows():
    df_blocking_hop10.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop11.iterrows():
    df_blocking_hop11.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop12.iterrows():
    df_blocking_hop12.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop13.iterrows():
    df_blocking_hop13.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop14.iterrows():
    df_blocking_hop14.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop15.iterrows():
    df_blocking_hop15.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop99999.iterrows():
    df_blocking_hop99999.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]

# %%
df_blocking_hop2 =  df_blocking_hop2.replace(0, np.NaN)
df_blocking_hop3 =  df_blocking_hop3.replace(0, np.NaN)
df_blocking_hop4 =  df_blocking_hop4.replace(0, np.NaN)
df_blocking_hop5 =  df_blocking_hop5.replace(0, np.NaN)
df_blocking_hop6 =  df_blocking_hop6.replace(0, np.NaN)
df_blocking_hop7 =  df_blocking_hop7.replace(0, np.NaN)
df_blocking_hop8 =  df_blocking_hop8.replace(0, np.NaN)
df_blocking_hop9 =  df_blocking_hop9.replace(0, np.NaN)
df_blocking_hop10 =  df_blocking_hop10.replace(0, np.NaN)
df_blocking_hop11 =  df_blocking_hop11.replace(0, np.NaN)
df_blocking_hop12 =  df_blocking_hop12.replace(0, np.NaN)
df_blocking_hop13 =  df_blocking_hop13.replace(0, np.NaN)
df_blocking_hop14 =  df_blocking_hop14.replace(0, np.NaN)
df_blocking_hop15 =  df_blocking_hop15.replace(0, np.NaN)
df_blocking_hop99999 =  df_blocking_hop99999.replace(0, np.NaN)

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")
plt.minorticks_off()
plt.plot(df_blocking_hop2['load'], df_blocking_hop2['Without defragmentation'], marker='x',  color="black")
plt.plot(df_blocking_hop2['load'], df_blocking_hop2['Conventional'], label=('Conventional'), marker='^',  color="red",  linestyle='-')

plt.plot(df_blocking_hop2['load'], df_blocking_hop2['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 2)'), marker='.',  color="blue", linestyle='-')

plt.plot(df_blocking_hop5['load'], df_blocking_hop5['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 5)'), marker='.',  color="blue", linestyle='--')

plt.plot(df_blocking_hop7['load'], df_blocking_hop7['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 7)'), marker='.',  color="blue", linestyle='-.')

plt.plot(df_blocking_hop10['load'], df_blocking_hop10['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 10)'), marker='.',  color="blue", linestyle=':')

plt.xlabel("Traffic load [Erlang]", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="lower right")
plt.savefig("../../sawa_paper/sawa/20180921_journal/fig/net11_hop.pdf")
plt.show()
plt.close()

# %%
df_ramda60 = pd.DataFrame(df_blocking_hop2.iloc[0]).T.rename(index={0:2})
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop3.iloc[0]).T.rename(index={0:3}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop4.iloc[0]).T.rename(index={0:4}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop5.iloc[0]).T.rename(index={0:5}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop6.iloc[0]).T.rename(index={0:6}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop7.iloc[0]).T.rename(index={0:7}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop8.iloc[0]).T.rename(index={0:8}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop9.iloc[0]).T.rename(index={0:9}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop10.iloc[0]).T.rename(index={0:10}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop11.iloc[0]).T.rename(index={0:11}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop12.iloc[0]).T.rename(index={0:12}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop13.iloc[0]).T.rename(index={0:13}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop14.iloc[0]).T.rename(index={0:14}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop15.iloc[0]).T.rename(index={0:15}))
df_ramda60
# Out:
#     load  speed  Without defragmentation  Conventional  Proposed  \
# 2   60.0    1.0                    0.001        0.0005    0.9099
# 3   60.0    1.0                    0.001        0.0005    0.6390
# 4   60.0    1.0                    0.001        0.0005    0.3098
# 5   60.0    1.0                    0.001        0.0005    0.1637
# 6   60.0    1.0                    0.001        0.0005    0.0551
# 7   60.0    1.0                    0.001        0.0005    0.0001
# 8   60.0    1.0                    0.001        0.0005    0.0004
# 9   60.0    1.0                    0.001        0.0005    0.0003
# 10  60.0    1.0                    0.001        0.0005    0.0004
# 11  60.0    1.0                    0.001        0.0005    0.0004
# 12  60.0    1.0                    0.001        0.0005    0.0004
# 13  60.0    1.0                    0.001        0.0005    0.0004
# 14  60.0    1.0                    0.001        0.0005    0.0004
# ...

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")

plt.plot(df_ramda60.index, df_ramda60['Without defragmentation'], label=('Without defragmentation'), marker='.',  color="black", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Conventional'], label=('Conventional (' + r'$\lambda$' + ' = 60)'), marker='.',  color="red", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Proposed'], label=('Proposed (' + r'$\lambda$' + ' = 60)'), marker='.',  color="blue", linestyle='-')

plt.xticks([2, 5, 10, 15])

plt.minorticks_off()

plt.xlabel("Maximum allowable number of hops", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="upper right")
plt.savefig("../../sawa_paper/sawa/20180921_journal/fig/net11_hop_num.pdf")
plt.show()
plt.close()
