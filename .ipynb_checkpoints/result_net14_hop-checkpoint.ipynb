# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import pylab
from pylab import rcParams

# %%
df_blocking_hop2 = pd.read_csv('../20181018_nsf_sp05_hop2/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop3 = pd.read_csv('../20181018_nsf_sp05_hop3/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop4 = pd.read_csv('../20181018_nsf_sp05_hop4/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop5 = pd.read_csv('../20181018_nsf_sp05_hop5/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop6 = pd.read_csv('../20181018_nsf_sp05_hop6/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop7 = pd.read_csv('../20181018_nsf_sp05_hop7/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop8 = pd.read_csv('../20181018_nsf_sp05_hop8/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop9 = pd.read_csv('../20181018_nsf_sp05_hop9/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop10 = pd.read_csv('../20181018_nsf_sp05_hop10/blocked_205_b.csv', names = ('load', 'speed', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )

# %%
df_blocking_hop5
# Out:
#    load  speed  Without defragmentation  Conventional  Proposed  \
# 0   120      1                       25            15         0
# 1   130      1                       82            53         1
# 2   140      1                      170           122        11
# 3   150      1                      297           228        42
# 4   160      1                      442           352       131
# 5   170      1                      578           508       256
# 6   180      1                      762           662       384
# 7   190      1                      930           823       549
# 8   200      1                     1069           974       744
# 9   210      1                     1221          1100       899
#
#    Conventional with SSR-LNO  Proposed with SSRR-LNO
# 0                          0                       0
# 1                          0                       0
# 2                          0                       0
# ...

# %%
df_blocking_hop4
# Out:
#    load  speed  Without defragmentation  Conventional  Proposed  \
# 0   120      1                       25            15       681
# 1   130      1                       82            53       678
# 2   140      1                      170           122       683
# 3   150      1                      297           228       689
# 4   160      1                      442           352       727
# 5   170      1                      578           508       785
# 6   180      1                      762           662       872
# 7   190      1                      930           823       988
# 8   200      1                     1069           974      1096
# 9   210      1                     1221          1100      1231
#
#    Conventional with SSR-LNO  Proposed with SSRR-LNO
# 0                          0                       0
# 1                          0                       0
# 2                          0                       0
# ...

# %%
for index, row in df_blocking_hop2.iterrows():
    df_blocking_hop2.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop3.iterrows():
    df_blocking_hop3.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop4.iterrows():
    df_blocking_hop4.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop5.iterrows():
    df_blocking_hop5.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop6.iterrows():
    df_blocking_hop6.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop7.iterrows():
    df_blocking_hop7.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop8.iterrows():
    df_blocking_hop8.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop9.iterrows():
    df_blocking_hop9.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop10.iterrows():
    df_blocking_hop10.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]

# %%
df_blocking_hop2 =  df_blocking_hop2.replace(0, np.NaN)
df_blocking_hop3 =  df_blocking_hop3.replace(0, np.NaN)
df_blocking_hop4 =  df_blocking_hop4.replace(0, np.NaN)
df_blocking_hop5 =  df_blocking_hop5.replace(0, np.NaN)
df_blocking_hop6 =  df_blocking_hop6.replace(0, np.NaN)
df_blocking_hop7 =  df_blocking_hop7.replace(0, np.NaN)
df_blocking_hop8 =  df_blocking_hop8.replace(0, np.NaN)
df_blocking_hop9 =  df_blocking_hop9.replace(0, np.NaN)
df_blocking_hop10 =  df_blocking_hop10.replace(0, np.NaN)

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")
plt.minorticks_off()
plt.plot(df_blocking_hop2['load'], df_blocking_hop2['Without defragmentation'], marker='x',  color="black")
plt.plot(df_blocking_hop2['load'], df_blocking_hop2['Conventional'], label=('Conventional'), marker='^',  color="red",  linestyle='-')

plt.plot(df_blocking_hop2['load'], df_blocking_hop2['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 2)'), marker='.',  color="blue", linestyle='-')

plt.plot(df_blocking_hop4['load'], df_blocking_hop4['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 4)'), marker='.',  color="blue", linestyle='--')

plt.plot(df_blocking_hop6['load'], df_blocking_hop6['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 6)'), marker='.',  color="blue", linestyle='-.')

plt.plot(df_blocking_hop10['load'], df_blocking_hop10['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 10)'), marker='.',  color="blue", linestyle=':')

plt.yticks([1,0.1, 0.01,0.001, 0.0001])

plt.xlabel("Traffic load [Erlang]", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="lower right")
plt.savefig("../../sawa_paper/sawa/20180921_journal/fig/net14_hop.pdf")
plt.show()

# %%
df_ramda60 = pd.DataFrame(df_blocking_hop2.iloc[1]).T.rename(index={1:2})
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop3.iloc[1]).T.rename(index={1:3}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop4.iloc[1]).T.rename(index={1:4}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop5.iloc[1]).T.rename(index={1:5}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop6.iloc[1]).T.rename(index={1:6}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop7.iloc[1]).T.rename(index={1:7}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop8.iloc[1]).T.rename(index={1:8}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop9.iloc[1]).T.rename(index={1:9}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop10.iloc[1]).T.rename(index={1:10}))
df_ramda60
# Out:
#      load  speed  Without defragmentation  Conventional  Proposed  \
# 2   130.0    1.0                   0.0082        0.0053    0.8806
# 3   130.0    1.0                   0.0082        0.0053    0.4907
# 4   130.0    1.0                   0.0082        0.0053    0.0678
# 5   130.0    1.0                   0.0082        0.0053    0.0001
# 6   130.0    1.0                   0.0082        0.0053    0.0001
# 7   130.0    1.0                   0.0082        0.0053    0.0001
# 8   130.0    1.0                   0.0082        0.0053    0.0004
# 9   130.0    1.0                   0.0082        0.0053    0.0006
# 10  130.0    1.0                   0.0082        0.0053    0.0005
#
#     Conventional with SSR-LNO  Proposed with SSRR-LNO
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
# ...

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")

plt.plot(df_ramda60.index, df_ramda60['Without defragmentation'], label=('Without defragmentation'), marker='.',  color="black", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Conventional'], label=('Conventional (' + r'$\lambda$' + ' = 130)'), marker='.',  color="red", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Proposed'], label=('Proposed (' + r'$\lambda$' + ' = 130)'), marker='.',  color="blue", linestyle='-')

plt.minorticks_off()

plt.xlabel("Maximum allowable number of hops", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="upper right")
plt.savefig("../../sawa_paper/sawa/20180921_journal/fig/net14_hop_num.pdf")
plt.show()
plt.close()
