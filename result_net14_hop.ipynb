# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import pylab
from pylab import rcParams

# %%
df_blocking_hop2  = pd.read_csv('../20181219_hop_nsf_2/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop3  = pd.read_csv('../20181219_hop_nsf_3/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop4  = pd.read_csv('../20181219_hop_nsf_4/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop5  = pd.read_csv('../20181219_hop_nsf_5/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop6  = pd.read_csv('../20181219_hop_nsf_6/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop7  = pd.read_csv('../20181219_hop_nsf_7/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop8  = pd.read_csv('../20181219_hop_nsf_8/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
df_blocking_hop9  = pd.read_csv('../20181219_hop_nsf_9/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )
# df_blocking_hop10 = pd.read_csv('../20181219_hop_nsf_10/result.csv', names = ('load', 'Without defragmentation', 'Conventional', 'Proposed', 'Conventional with SSR-LNO', 'Proposed with SSRR-LNO') )

# %%
for index, row in df_blocking_hop2.iterrows():
    df_blocking_hop2.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop3.iterrows():
    df_blocking_hop3.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop4.iterrows():
    df_blocking_hop4.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop5.iterrows():
    df_blocking_hop5.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop6.iterrows():
    df_blocking_hop6.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop7.iterrows():
    df_blocking_hop7.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop8.iterrows():
    df_blocking_hop8.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
for index, row in df_blocking_hop9.iterrows():
    df_blocking_hop9.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]
# for index, row in df_blocking_hop10.iterrows():
#     df_blocking_hop10.loc[index, 'Without defragmentation':'Proposed with SSRR-LNO'] /= [10000, 10000, 10000, 10000, 10000]

# %%
df_blocking_hop2 =  df_blocking_hop2.replace(0, np.NaN)
df_blocking_hop3 =  df_blocking_hop3.replace(0, np.NaN)
df_blocking_hop4 =  df_blocking_hop4.replace(0, np.NaN)
df_blocking_hop5 =  df_blocking_hop5.replace(0, np.NaN)
df_blocking_hop6 =  df_blocking_hop6.replace(0, np.NaN)
df_blocking_hop7 =  df_blocking_hop7.replace(0, np.NaN)
df_blocking_hop8 =  df_blocking_hop8.replace(0, np.NaN)
df_blocking_hop9 =  df_blocking_hop9.replace(0, np.NaN)
# df_blocking_hop10 =  df_blocking_hop10.replace(0, np.NaN)

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 17
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")
plt.minorticks_off()
plt.plot(df_blocking_hop4['load'], df_blocking_hop4['Without defragmentation'], marker='x',  color="black")
plt.plot(df_blocking_hop4['load'], df_blocking_hop4['Conventional'], label=('Conventional'), marker='^',  color="red",  linestyle='-')

plt.plot(df_blocking_hop4['load'], df_blocking_hop4['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 4)'), marker='.',  color="blue", linestyle='-')

plt.plot(df_blocking_hop5['load'], df_blocking_hop5['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 5)'), marker='.',  color="blue", linestyle='--')

# plt.plot(df_blocking_hop6['load'], df_blocking_hop6['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 6)'), marker='.',  color="blue", linestyle='-')

plt.plot(df_blocking_hop9['load'], df_blocking_hop9['Proposed'], label=('Proposed (' + r'$\sigma$' + ' = 9)'), marker='.',  color="blue", linestyle=':')

plt.yticks([1,0.1, 0.01,0.001, 0.0001])

plt.xlabel("Traffic load [Erlang]", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="lower right")
plt.savefig("../../sawa_paper/sawa/20181223_journal_sawa/fig/net14_hop.pdf")
plt.show()

# %%
df_ramda60 = pd.DataFrame(df_blocking_hop2.iloc[2]).T.rename(index={1:2})
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop3.iloc[2]).T.rename(index={2:3}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop4.iloc[2]).T.rename(index={2:4}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop5.iloc[2]).T.rename(index={2:5}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop6.iloc[2]).T.rename(index={2:6}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop7.iloc[2]).T.rename(index={2:7}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop8.iloc[2]).T.rename(index={2:8}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop9.iloc[2]).T.rename(index={2:9}))
df_ramda60 = df_ramda60.append(pd.DataFrame(df_blocking_hop10.iloc[2]).T.rename(index={2:10}))
df_ramda60
# Out:
#      load  Without defragmentation  Conventional  Proposed  \
# 2   160.0                   0.0290        0.0063    0.0190
# 3   160.0                   0.0293        0.0059    0.0034
# 4   160.0                   0.0302        0.0069    0.0003
# 5   160.0                   0.0297        0.0066    0.0002
# 6   160.0                   0.0302        0.0063    0.0003
# 7   160.0                   0.0311        0.0068    0.0004
# 8   160.0                   0.0291        0.0058    0.0003
# 9   160.0                   0.0292        0.0062    0.0003
# 10  160.0                   0.0299        0.0062    0.0003
#
#     Conventional with SSR-LNO  Proposed with SSRR-LNO
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# ...

# %%
ave = df_ramda60.mean()
for index, row in df_ramda60.iterrows():
    df_ramda60.loc[index, 'Without defragmentation'] = ave['Without defragmentation']
    df_ramda60.loc[index, 'Conventional'] = ave['Conventional']

# %%
plt.clf()
pylab.figure(figsize=(7, 7))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.gca().yaxis.set_ticks_position('left')
plt.gca().xaxis.set_ticks_position('bottom')
plt.rcParams['font.family'] ='Times New Roman'
plt.rcParams['font.weight'] = 'light'
plt.rcParams['font.size'] = 22
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['legend.borderaxespad'] = 0
plt.rcParams['legend.frameon'] = False
plt.rcParams['legend.numpoints'] = 1
plt.rcParams['legend.labelspacing'] = 0.1
plt.rcParams['savefig.bbox'] = 'tight'

# %%
plt.yscale("log")

plt.plot(df_ramda60.index, df_ramda60['Without defragmentation'], label=('Without defragmentation'), marker='.',  color="black", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Conventional'], label=('Conventional (' + r'$\lambda$' + ' = 160)'), marker='.',  color="red", linestyle='-')

plt.plot(df_ramda60.index, df_ramda60['Proposed'], label=('Proposed (' + r'$\lambda$' + ' = 160)'), marker='.',  color="blue", linestyle='-')

plt.minorticks_off()

plt.xticks([2, 3, 4, 5, 6, 7, 8, 9, 10])
plt.yticks([1,0.1,0.01,0.001, 0.0001])

plt.xlabel("Maximum allowable number of hops", weight=1) # x軸のタイトル
plt.ylabel("Blocking probability") # y軸
plt.legend(loc="upper right")
plt.savefig("../../sawa_paper/sawa/20181211_journal_sawa/fig/net14_hop_num.pdf")
plt.show()
plt.close()
